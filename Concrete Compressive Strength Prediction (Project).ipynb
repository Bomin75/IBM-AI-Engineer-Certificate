# %% [markdown]
# # Concrete Strength Prediction
# : build a regression model using the Keras library that predicts the compressive strength of concrete
#
# concrete_data.csv contains the following features:
# 1. Cement: the amount of cement mixed, in m<sup>3<sup/>
# 2. Blast Furnace Slag: the amount of blast furnace slag mixed, in m<sup>3<sup/>
# 3. Fly Ash: the amount of fly ash mixed, in m<sup>3<sup/>
# 4. Water: the amount of water mixed, in m<sup>3<sup/>
# 5. Superplasticizer: the amount of superplasticizer mixed, in m<sup>3<sup/>
# 6. Coarse Aggregate: the amount of coarse aggregate mixed, in m<sup>3<sup/>
# 7. Fine Aggregate: the amount of fine aggregate mixed, in m<sup>3<sup/>
# 8. Age: the age of a concrete, in days
#
# The main objectives of this project is to figure out how data normalization, the number of epochs, and the number of hidden layers influence the performance of a neural network.

# %%
# import modules
import keras
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
# Out:
# 2024-05-15 03:06:41.911976: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Build a baseline model

# %%
# load the dataset from csv file
concrete_data = pd.read_csv('concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
# split the dataset
predictors = concrete_data.drop(columns='Strength', inplace=False)
target = concrete_data[['Strength']]
predictors_train, predictors_test, target_train, target_test = train_test_split(predictors, target, test_size=0.3, random_state=5)

# %%
# build a neural network
def regression_model(features, activation, optimizer, loss):
    model = Sequential()
    
    n_cols = features.shape[1]
    
    model.add(Dense(10, activation=activation, input_shape=(n_cols,)))
    model.add(Dense(1))
    
    model.compile(optimizer=optimizer, loss=loss)
    return model

# %%
def train_regression_model(model, features_train, targets_train, features_test, targets_test, epochs):
    # fit the model
    model.fit(features_train, targets_train, epochs=epochs, verbose=0)
    
    # evaluate the model
    predictions = model.predict(features_test)
    MSE = mean_squared_error(targets_test, predictions)
    print('Mean squared error of this model is: {}'.format(np.around(MSE, decimals=4)))
    return MSE
model = regression_model(predictors, 'relu', 'adam', 'mean_squared_error')
train_regression_model(model, predictors_train, target_train, predictors_test, target_test, 50)
# Out:
# 10/10 [==============================] - 0s 835us/step
# Mean squared error of this model is: 543.8628
# 543.862820964712

# %%
# train 50 times; get the mean and the standard deviation
MSEs = []
for i in range(50):
    MSEs.append(train_regression_model(model, predictors_train, target_train, predictors_test, target_test, 50))
MSEs = np.array(MSEs)
# Out:
# 10/10 [==============================] - 0s 913us/step
# Mean squared error of this model is: 251.5042
# 10/10 [==============================] - 0s 870us/step
# Mean squared error of this model is: 182.9886
# 10/10 [==============================] - 0s 827us/step
# Mean squared error of this model is: 143.3611
# 10/10 [==============================] - 0s 975us/step
# Mean squared error of this model is: 116.3093
# 10/10 [==============================] - 0s 781us/step
# Mean squared error of this model is: 108.9885
# 10/10 [==============================] - 0s 836us/step
# Mean squared error of this model is: 107.9778
# 10/10 [==============================] - 0s 818us/step
# Mean squared error of this model is: 109.7633
# 10/10 [==============================] - 0s 768us/step
# Mean squared error of this model is: 108.2241
# 10/10 [==============================] - 0s 869us/step
# Mean squared error of this model is: 113.6541
# 10/10 [==============================] - 0s 1ms/step
# Mean squared error of this model is: 108.1719
# 10/10 [==============================] - 0s 778us/step
# Mean squared error of this model is: 107.9627
# 10/10 [==============================] - 0s 788us/step
# Mean squared error of this model is: 111.5672
# 10/10 [==============================] - 0s 765us/step
# Mean squared error of this model is: 114.7291
# 10/10 [==============================] - 0s 821us/step
# Mean squared error of this model is: 111.64
# 10/10 [==============================] - 0s 782us/step
# Mean squared error of this model is: 109.6346
# 10/10 [==============================] - 0s 2ms/step
# Mean squared error of this model is: 107.6573
# 10/10 [==============================] - 0s 735us/step
# Mean squared error of this model is: 112.9737
# 10/10 [==============================] - 0s 708us/step
# Mean squared error of this model is: 114.5837
# 10/10 [==============================] - 0s 1ms/step
# Mean squared error of this model is: 109.4837
# 10/10 [==============================] - 0s 745us/step
# Mean squared error of this model is: 108.3797
# 10/10 [==============================] - 0s 818us/step
# Mean squared error of this model is: 109.4824
# 10/10 [==============================] - 0s 803us/step
# Mean squared error of this model is: 108.1299
# 10/10 [==============================] - 0s 984us/step
# Mean squared error of this model is: 110.6
# 10/10 [==============================] - 0s 871us/step
# Mean squared error of this model is: 108.7191
# 10/10 [==============================] - 0s 766us/step
# Mean squared error of this model is: 108.2377
# 10/10 [==============================] - 0s 940us/step
# Mean squared error of this model is: 108.2139
# 10/10 [==============================] - 0s 795us/step
# Mean squared error of this model is: 109.6657
# 10/10 [==============================] - 0s 765us/step
# Mean squared error of this model is: 113.2103
# 10/10 [==============================] - 0s 622us/step
# Mean squared error of this model is: 109.4358
# 10/10 [==============================] - 0s 988us/step
# Mean squared error of this model is: 108.219
# 10/10 [==============================] - 0s 806us/step
# Mean squared error of this model is: 108.1634
# 10/10 [==============================] - 0s 745us/step
# Mean squared error of this model is: 108.4128
# 10/10 [==============================] - 0s 850us/step
# Mean squared error of this model is: 109.3024
# 10/10 [==============================] - 0s 823us/step
# Mean squared error of this model is: 79.4615
# 10/10 [==============================] - 0s 763us/step
# Mean squared error of this model is: 76.8904
# 10/10 [==============================] - 0s 851us/step
# Mean squared error of this model is: 79.5036
# 10/10 [==============================] - 0s 799us/step
# Mean squared error of this model is: 73.1862
# 10/10 [==============================] - 0s 866us/step
# Mean squared error of this model is: 71.8803
# 10/10 [==============================] - 0s 889us/step
# Mean squared error of this model is: 70.9527
# 10/10 [==============================] - 0s 776us/step
# Mean squared error of this model is: 63.6031
# 10/10 [==============================] - 0s 819us/step
# Mean squared error of this model is: 58.4129
# 10/10 [==============================] - 0s 831us/step
# Mean squared error of this model is: 55.5373
# 10/10 [==============================] - 0s 791us/step
# Mean squared error of this model is: 54.5781
# 10/10 [==============================] - 0s 912us/step
# Mean squared error of this model is: 53.4232
# 10/10 [==============================] - 0s 799us/step
# Mean squared error of this model is: 52.6311
# 10/10 [==============================] - 0s 970us/step
# Mean squared error of this model is: 53.6387
# 10/10 [==============================] - 0s 829us/step
# Mean squared error of this model is: 52.8668
# 10/10 [==============================] - 0s 772us/step
# Mean squared error of this model is: 52.9005
# 10/10 [==============================] - 0s 737us/step
# Mean squared error of this model is: 53.465
# 10/10 [==============================] - 0s 789us/step
# Mean squared error of this model is: 52.4744

# %%
mean = np.around(MSEs.mean(), decimals=4).astype(str)
std = np.around(MSEs.std(), decimals=4).astype(str)
print('The mean of the mean squared errors is ' + mean + ', and the standard deviation of the mean squared error is ' + std)
# Out:
# The mean of the mean squared errors is 394.2581, and the standard deviation of the mean squared error is 623.0284

# %% [markdown]
# Mean: 394.2581
# Standard Deviation: 623.0284

# %% [markdown]
# ## Training with a normalized data

# %%
# normalize data
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm_train, predictors_norm_test, target_train, target_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=5)

# train data
model = regression_model(predictors_norm, 'relu', 'adam', 'mean_squared_error')
train_regression_model(model, predictors_norm_train, target_train, predictors_norm_test, target_test, 50)
# Out:
# 10/10 [==============================] - 0s 845us/step
# Mean squared error of this model is: 312.6012
# 312.60124277852447

# %%
# train 50 times; get the mean and the standard deviation
MSEs = []
for i in range(50):
    MSEs.append(train_regression_model(model, predictors_norm_train, target_train, predictors_norm_test, target_test, 50))
MSEs = np.array(MSEs)
mean = np.around(MSEs.mean(), decimals=4).astype(str)
std = np.around(MSEs.std(), decimals=4).astype(str)
print('The mean of the mean squared errors is ' + mean + ', and the standard deviation of the mean squared error is ' + std)
# Out:
# 10/10 [==============================] - 0s 1ms/step
# Mean squared error of this model is: 164.3544
# 10/10 [==============================] - 0s 850us/step
# Mean squared error of this model is: 131.3273
# 10/10 [==============================] - 0s 826us/step
# Mean squared error of this model is: 104.4418
# 10/10 [==============================] - 0s 911us/step
# Mean squared error of this model is: 84.7311
# 10/10 [==============================] - 0s 930us/step
# Mean squared error of this model is: 70.6504
# 10/10 [==============================] - 0s 828us/step
# Mean squared error of this model is: 62.528
# 10/10 [==============================] - 0s 757us/step
# Mean squared error of this model is: 58.0033
# 10/10 [==============================] - 0s 860us/step
# Mean squared error of this model is: 55.2918
# 10/10 [==============================] - 0s 795us/step
# Mean squared error of this model is: 53.5045
# 10/10 [==============================] - 0s 920us/step
# Mean squared error of this model is: 52.0842
# 10/10 [==============================] - 0s 849us/step
# Mean squared error of this model is: 51.1193
# 10/10 [==============================] - 0s 928us/step
# Mean squared error of this model is: 50.2552
# 10/10 [==============================] - 0s 735us/step
# Mean squared error of this model is: 49.2906
# 10/10 [==============================] - 0s 1ms/step
# Mean squared error of this model is: 48.1269
# 10/10 [==============================] - 0s 759us/step
# Mean squared error of this model is: 47.4974
# 10/10 [==============================] - 0s 1ms/step
# Mean squared error of this model is: 47.0585
# 10/10 [==============================] - 0s 964us/step
# Mean squared error of this model is: 46.7353
# 10/10 [==============================] - 0s 746us/step
# Mean squared error of this model is: 46.6137
# 10/10 [==============================] - 0s 763us/step
# Mean squared error of this model is: 45.977
# 10/10 [==============================] - 0s 1ms/step
# Mean squared error of this model is: 45.7227
# 10/10 [==============================] - 0s 774us/step
# Mean squared error of this model is: 45.2664
# 10/10 [==============================] - 0s 734us/step
# Mean squared error of this model is: 45.2073
# 10/10 [==============================] - 0s 763us/step
# Mean squared error of this model is: 45.0272
# 10/10 [==============================] - 0s 803us/step
# Mean squared error of this model is: 44.9066
# 10/10 [==============================] - 0s 744us/step
# Mean squared error of this model is: 44.8065
# 10/10 [==============================] - 0s 814us/step
# Mean squared error of this model is: 44.4504
# 10/10 [==============================] - 0s 778us/step
# Mean squared error of this model is: 44.4977
# 10/10 [==============================] - 0s 740us/step
# Mean squared error of this model is: 44.2361
# 10/10 [==============================] - 0s 801us/step
# Mean squared error of this model is: 44.1708
# 10/10 [==============================] - 0s 739us/step
# Mean squared error of this model is: 44.1419
# 10/10 [==============================] - 0s 937us/step
# Mean squared error of this model is: 44.1042
# 10/10 [==============================] - 0s 758us/step
# Mean squared error of this model is: 43.9958
# 10/10 [==============================] - 0s 744us/step
# Mean squared error of this model is: 43.9928
# 10/10 [==============================] - 0s 883us/step
# Mean squared error of this model is: 43.7586
# 10/10 [==============================] - 0s 746us/step
# Mean squared error of this model is: 43.7953
# 10/10 [==============================] - 0s 816us/step
# Mean squared error of this model is: 43.6523
# 10/10 [==============================] - 0s 732us/step
# Mean squared error of this model is: 43.681
# 10/10 [==============================] - 0s 780us/step
# Mean squared error of this model is: 43.582
# 10/10 [==============================] - 0s 750us/step
# Mean squared error of this model is: 43.092
# 10/10 [==============================] - 0s 925us/step
# Mean squared error of this model is: 43.3991
# 10/10 [==============================] - 0s 847us/step
# Mean squared error of this model is: 43.2063
# 10/10 [==============================] - 0s 819us/step
# Mean squared error of this model is: 43.2621
# 10/10 [==============================] - 0s 2ms/step
# Mean squared error of this model is: 43.1777
# 10/10 [==============================] - 0s 837us/step
# Mean squared error of this model is: 43.0922
# 10/10 [==============================] - 0s 792us/step
# Mean squared error of this model is: 42.8595
# 10/10 [==============================] - 0s 841us/step
# Mean squared error of this model is: 43.1682
# 10/10 [==============================] - 0s 828us/step
# Mean squared error of this model is: 43.0187
# 10/10 [==============================] - 0s 911us/step
# Mean squared error of this model is: 43.0248
# 10/10 [==============================] - 0s 864us/step
# Mean squared error of this model is: 43.0703
# 10/10 [==============================] - 0s 812us/step
# Mean squared error of this model is: 43.3882
# The mean of the mean squared errors is 52.6069, and the standard deviation of the mean squared error is 22.5591

# %% [markdown]
# Mean: 52.6069 Standard Deviation: 22.5591

# %% [markdown]
# ## Increase in epochs

# %%
# train 50 times; get the mean and the standard deviation
MSEs = []
for i in range(50):
    MSEs.append(train_regression_model(model, predictors_norm_train, target_train, predictors_norm_test, target_test, 100))
MSEs = np.array(MSEs)
mean = np.around(MSEs.mean(), decimals=4).astype(str)
std = np.around(MSEs.std(), decimals=4).astype(str)
print('The mean of the mean squared errors is ' + mean + ', and the standard deviation of the mean squared error is ' + std)
# Out:
# 10/10 [==============================] - 0s 733us/step
# Mean squared error of this model is: 43.0065
# 10/10 [==============================] - 0s 842us/step
# Mean squared error of this model is: 43.4582
# 10/10 [==============================] - 0s 717us/step
# Mean squared error of this model is: 43.3447
# 10/10 [==============================] - 0s 931us/step
# Mean squared error of this model is: 43.0557
# 10/10 [==============================] - 0s 833us/step
# Mean squared error of this model is: 43.0397
# 10/10 [==============================] - 0s 781us/step
# Mean squared error of this model is: 42.8587
# 10/10 [==============================] - 0s 800us/step
# Mean squared error of this model is: 42.648
# 10/10 [==============================] - 0s 770us/step
# Mean squared error of this model is: 42.3821
# 10/10 [==============================] - 0s 855us/step
# Mean squared error of this model is: 42.3071
# 10/10 [==============================] - 0s 761us/step
# Mean squared error of this model is: 42.3671
# 10/10 [==============================] - 0s 1ms/step
# Mean squared error of this model is: 41.9
# 10/10 [==============================] - 0s 757us/step
# Mean squared error of this model is: 42.1418
# 10/10 [==============================] - 0s 753us/step
# Mean squared error of this model is: 42.0712
# 10/10 [==============================] - 0s 739us/step
# Mean squared error of this model is: 41.5343
# 10/10 [==============================] - 0s 747us/step
# Mean squared error of this model is: 41.5814
# 10/10 [==============================] - 0s 864us/step
# Mean squared error of this model is: 41.7064
# 10/10 [==============================] - 0s 726us/step
# Mean squared error of this model is: 42.043
# 10/10 [==============================] - 0s 886us/step
# Mean squared error of this model is: 41.8426
# 10/10 [==============================] - 0s 746us/step
# Mean squared error of this model is: 41.9537
# 10/10 [==============================] - 0s 1ms/step
# Mean squared error of this model is: 41.8461
# 10/10 [==============================] - 0s 839us/step
# Mean squared error of this model is: 41.8392
# 10/10 [==============================] - 0s 917us/step
# Mean squared error of this model is: 41.862
# 10/10 [==============================] - 0s 1ms/step
# Mean squared error of this model is: 41.9962
# 10/10 [==============================] - 0s 922us/step
# Mean squared error of this model is: 41.5999
# 10/10 [==============================] - 0s 969us/step
# Mean squared error of this model is: 41.6109
# 10/10 [==============================] - 0s 751us/step
# Mean squared error of this model is: 41.479
# 10/10 [==============================] - 0s 2ms/step
# Mean squared error of this model is: 41.5284
# 10/10 [==============================] - 0s 753us/step
# Mean squared error of this model is: 41.573
# 10/10 [==============================] - 0s 753us/step
# Mean squared error of this model is: 41.305
# 10/10 [==============================] - 0s 730us/step
# Mean squared error of this model is: 41.143
# 10/10 [==============================] - 0s 782us/step
# Mean squared error of this model is: 41.0777
# 10/10 [==============================] - 0s 754us/step
# Mean squared error of this model is: 41.3189
# 10/10 [==============================] - 0s 867us/step
# Mean squared error of this model is: 41.4836
# 10/10 [==============================] - 0s 767us/step
# Mean squared error of this model is: 41.4233
# 10/10 [==============================] - 0s 748us/step
# Mean squared error of this model is: 41.5139
# 10/10 [==============================] - 0s 918us/step
# Mean squared error of this model is: 41.2509
# 10/10 [==============================] - 0s 762us/step
# Mean squared error of this model is: 41.6108
# 10/10 [==============================] - 0s 751us/step
# Mean squared error of this model is: 41.5974
# 10/10 [==============================] - 0s 791us/step
# Mean squared error of this model is: 41.5131
# 10/10 [==============================] - 0s 756us/step
# Mean squared error of this model is: 41.8226
# 10/10 [==============================] - 0s 800us/step
# Mean squared error of this model is: 41.602
# 10/10 [==============================] - 0s 728us/step
# Mean squared error of this model is: 41.6064
# 10/10 [==============================] - 0s 868us/step
# Mean squared error of this model is: 41.699
# 10/10 [==============================] - 0s 715us/step
# Mean squared error of this model is: 41.7729
# 10/10 [==============================] - 0s 741us/step
# Mean squared error of this model is: 41.4779
# 10/10 [==============================] - 0s 789us/step
# Mean squared error of this model is: 41.8141
# 10/10 [==============================] - 0s 752us/step
# Mean squared error of this model is: 41.784
# 10/10 [==============================] - 0s 782us/step
# Mean squared error of this model is: 41.7143
# 10/10 [==============================] - 0s 730us/step
# Mean squared error of this model is: 41.6958
# 10/10 [==============================] - 0s 720us/step
# Mean squared error of this model is: 41.9079
# The mean of the mean squared errors is 41.8942, and the standard deviation of the mean squared error is 0.5517

# %% [markdown]
# Mean: 41.8942 Standard Deviation: 0.5517

# %% [markdown]
# ## Increase in hidden layers

# %%
# build a neural network with three hidden layers
def regression_model(features, activation, optimizer, loss):
    model = Sequential()
    
    n_cols = features.shape[1]
    
    model.add(Dense(10, activation=activation, input_shape=(n_cols,)))
    model.add(Dense(10, activation=activation))
    model.add(Dense(10, activation=activation))
    model.add(Dense(1))
    
    model.compile(optimizer=optimizer, loss=loss)
    return model

# %%
# train 50 times; get the mean and the standard deviation
MSEs = []
for i in range(50):
    MSEs.append(train_regression_model(model, predictors_norm_train, target_train, predictors_norm_test, target_test, 50))
MSEs = np.array(MSEs)
mean = np.around(MSEs.mean(), decimals=4).astype(str)
std = np.around(MSEs.std(), decimals=4).astype(str)
print('The mean of the mean squared errors is ' + mean + ', and the standard deviation of the mean squared error is ' + std)
# Out:
# 10/10 [==============================] - 0s 822us/step
# Mean squared error of this model is: 42.0781
# 10/10 [==============================] - 0s 789us/step
# Mean squared error of this model is: 41.8161
# 10/10 [==============================] - 0s 779us/step
# Mean squared error of this model is: 41.846
# 10/10 [==============================] - 0s 739us/step
# Mean squared error of this model is: 41.9117
# 10/10 [==============================] - 0s 808us/step
# Mean squared error of this model is: 42.1016
# 10/10 [==============================] - 0s 745us/step
# Mean squared error of this model is: 41.9591
# 10/10 [==============================] - 0s 817us/step
# Mean squared error of this model is: 41.7605
# 10/10 [==============================] - 0s 868us/step
# Mean squared error of this model is: 41.7462
# 10/10 [==============================] - 0s 777us/step
# Mean squared error of this model is: 41.9702
# 10/10 [==============================] - 0s 794us/step
# Mean squared error of this model is: 41.653
# 10/10 [==============================] - 0s 784us/step
# Mean squared error of this model is: 41.9482
# 10/10 [==============================] - 0s 820us/step
# Mean squared error of this model is: 41.8665
# 10/10 [==============================] - 0s 718us/step
# Mean squared error of this model is: 42.0839
# 10/10 [==============================] - 0s 798us/step
# Mean squared error of this model is: 41.9461
# 10/10 [==============================] - 0s 744us/step
# Mean squared error of this model is: 41.6541
# 10/10 [==============================] - 0s 794us/step
# Mean squared error of this model is: 41.7352
# 10/10 [==============================] - 0s 716us/step
# Mean squared error of this model is: 41.9266
# 10/10 [==============================] - 0s 766us/step
# Mean squared error of this model is: 41.7832
# 10/10 [==============================] - 0s 760us/step
# Mean squared error of this model is: 42.112
# 10/10 [==============================] - 0s 845us/step
# Mean squared error of this model is: 42.1559
# 10/10 [==============================] - 0s 834us/step
# Mean squared error of this model is: 41.873
# 10/10 [==============================] - 0s 758us/step
# Mean squared error of this model is: 41.9233
# 10/10 [==============================] - 0s 917us/step
# Mean squared error of this model is: 42.0384
# 10/10 [==============================] - 0s 730us/step
# Mean squared error of this model is: 42.2851
# 10/10 [==============================] - 0s 803us/step
# Mean squared error of this model is: 42.019
# 10/10 [==============================] - 0s 823us/step
# Mean squared error of this model is: 42.1072
# 10/10 [==============================] - 0s 838us/step
# Mean squared error of this model is: 42.3725
# 10/10 [==============================] - 0s 795us/step
# Mean squared error of this model is: 42.0124
# 10/10 [==============================] - 0s 875us/step
# Mean squared error of this model is: 42.2987
# 10/10 [==============================] - 0s 932us/step
# Mean squared error of this model is: 42.0341
# 10/10 [==============================] - 0s 814us/step
# Mean squared error of this model is: 42.086
# 10/10 [==============================] - 0s 824us/step
# Mean squared error of this model is: 41.8055
# 10/10 [==============================] - 0s 833us/step
# Mean squared error of this model is: 42.1916
# 10/10 [==============================] - 0s 844us/step
# Mean squared error of this model is: 42.1726
# 10/10 [==============================] - 0s 782us/step
# Mean squared error of this model is: 42.1834
# 10/10 [==============================] - 0s 794us/step
# Mean squared error of this model is: 42.2373
# 10/10 [==============================] - 0s 799us/step
# Mean squared error of this model is: 41.9289
# 10/10 [==============================] - 0s 922us/step
# Mean squared error of this model is: 41.9029
# 10/10 [==============================] - 0s 801us/step
# Mean squared error of this model is: 42.185
# 10/10 [==============================] - 0s 760us/step
# Mean squared error of this model is: 42.1639
# 10/10 [==============================] - 0s 847us/step
# Mean squared error of this model is: 41.9913
# 10/10 [==============================] - 0s 2ms/step
# Mean squared error of this model is: 42.1882
# 10/10 [==============================] - 0s 851us/step
# Mean squared error of this model is: 42.0205
# 10/10 [==============================] - 0s 915us/step
# Mean squared error of this model is: 42.1127
# 10/10 [==============================] - 0s 701us/step
# Mean squared error of this model is: 41.9799
# 10/10 [==============================] - 0s 966us/step
# Mean squared error of this model is: 42.2929
# 10/10 [==============================] - 0s 823us/step
# Mean squared error of this model is: 41.8721
# 10/10 [==============================] - 0s 803us/step
# Mean squared error of this model is: 41.8591
# 10/10 [==============================] - 0s 810us/step
# Mean squared error of this model is: 41.8476
# 10/10 [==============================] - 0s 744us/step
# Mean squared error of this model is: 42.319
# The mean of the mean squared errors is 42.0072, and the standard deviation of the mean squared error is 0.1762

# %% [markdown]
# Mean: 42.0072 Standard Deviation: 0.1762

# %% [markdown]
# ### Conclusion
# * The most significant improvement in the performance of a neural network model was found from data normalization.
# * Increase in the number of epochs and the number of hidden layers had positive effects on the model's performace.
